# %% [markdown]
# ## Задача
# Необходимо создать модель, которая принимает на вход текст документа и наименование одного из двух пунктов, и возвращает возвращать соответствующий кусочек текста из текста документа (фрагмент, начало индекса фрагмента, конец индекса фрагмента)
#
# Пример
# ```
#     {'text': ['Размер обеспечения исполнения контракта 6593.25 Российский рубль'], [1279], [1343] }
# ```

# %%
import json
from sklearn.utils import shuffle
import re
import numpy as np
import pandas as pd
import ast
import random
from tqdm import tqdm
from spacy.tokens import DocBin
from spacy.util import filter_spans
import spacy
from spacy.training.example import Example
from spacy.lang.ru import Russian
from sklearn.model_selection import train_test_split
from spacy.training import offsets_to_biluo_tags

# %%
with open('dataset\\train.json', 'r', encoding='utf-8') as f: #открыли файл с данными
    data = json.load(f) #загнали все, что получилось в переменную
data[0]
# Out:
# {'id': 809436509,
#  'text': 'Извещение о проведении открытого конкурса в электронной форме для закупки №0328300032822000806 Общая информация Номер извещения 0328300032822000806 Наименование объекта закупки Поставка продуктов питания Способ определения поставщика (подрядчика, исполнителя) Открытый конкурс в бль Порядок внесения денежных средств в качестве обеспечения заявки на участие в закупке, а также условия гарантии Обеспечение заявки на участие в закупке может предоставляться участником закупки в виде денежных средств или независимой гарантии, предусмотренной ст. 45 Федерального закона № 44-ФЗ. Выбор способа обеспечения осуществляется участником закупки самостоятельно. Срок действия независимой гарантии должен составлять не менее месяца с даты окончания срока подачи заявок. Обеспечение заявки на участие в закупке предоставляется в соответствии с ч. 5 ст. 44 Федерального закона № 44-ФЗ. Условия независимой гарантии в соответствии со ст. 45 Федерального закона № 44-ФЗ. Реквизиты счета в соответствии с п.16 ч. 1 ст. 42 Закона № 44-ФЗ "Номер расчётного счёта" 00000000000000000000 "Номер лицевого счёта" См. прилагаемые документы "БИК" 000000000 "Наименование кредитной организации" "Номер корреспондентского счета" Обеспечение исполнения контракта Требуется обеспечение исполнения контракта Размер обеспечения исполнения контракта 6593.25 Российский рубль Порядок обеспечения исполнения контракта, требования к обеспечению Исполнение контракта, гарантийные обязательства могут обеспечиваться предоставлением независимой гарантии, соответствующей требованиям ст. 45 Федерального закона № 44-ФЗ, или внесением денежных средств на указанный заказчиком счет, на котором в соответствии с законодательством Российской Федерации учитываются операции со средствами, поступающими заказчику. Способ обеспечения исполнения контракта, гарантийных обязательств, срок действия независимой гарантии определяются в соответствии с требованиями Федерального закона № 44-ФЗ участником закупки, с которым заключается контракт, самостоятельно. При этом срок действия независимой гарантии должен превышать предусмотренный контрактом срок исполнения обязательств, которые должны быть обеспечены такой независимой гарантией, не менее чем на один месяц, в том числе в случае его изменения в соответствии со ст. 95 Федерального закона № 44-ФЗ. Порядок предоставления и требования о Информация и документы, подтверждающие соответствие участников закупки дополнительным требованиям: 1) исполненный договор; 2) акт приемки оказанных услуг и (или) поставленных товаров, подтверждающий цену оказанных услуг и (или) поставленных товаров 4',
#  'label': 'обеспечение исполнения контракта',
#  'extracted_part': {'text': ['Размер обеспечения исполнения контракта 6593.25 Российский рубль'],
#   'answer_start': [1279],
#   'answer_end': [1343]}}

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# ### Сделаем предварительную обработку данных, для обучения модели Spacy

# %%
labels_ner = {'обеспечение исполнения контракта': 'EC', 'обеспечение гарантийных обязательств': 'PWO'}
def preprocessing(data):
    nlp = spacy.blank("ru")
    data_train = []
    data_missing = []
    for dict in data:
        text = dict.get('text')
        label = labels_ner.get(dict.get('label'))
        answer_start = dict.get('extracted_part').get('answer_start')[0]
        answer_end = dict.get('extracted_part').get('answer_end')[0]

        doc = nlp(dict.get('text'))
        entities = [(answer_start, answer_end, label)]
        tags = offsets_to_biluo_tags(doc, entities)

        if (answer_start == 0 and answer_end == 0) or ('-' in tags):
            data_missing.append((text, {'entities': []}))
        else:
            #print(text[answer_start-10:answer_end+10])
            row = (text, {'entities': [(answer_start, answer_end, label)]})
            data_train.append(row)
    return data_train, data_missing

data_train, data_missing = preprocessing(data)
#data_train, data_valid = train_test_split(data_train, random_state=12345, test_size=0.25)
#data_valid+=data_missing

'''
data_train, data_valid = train_test_split(preprocessing(data), random_state=12345, test_size=0.25)
print(len(data_train))
print(len(data_valid))
data_train[0]
'''

print(len(data_train))
#print(len(data_valid))
data_train[0]
# Out:
# d:\Jupiter\venv\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "РАЗДЕЛ 4. тельно); в) 1 процент цены контракта, ес..." with entities "[(1010, 1179, 'EC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# d:\Jupiter\venv\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PAGE ПРОЕКТ КОНТРАКТА КОНТРАКТ № ______ на поставк..." with entities "[(1226, 1355, 'EC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# d:\Jupiter\venv\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "ПРОЕКТ Государственный контракт №________ на поста..." with entities "[(1193, 1314, 'EC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# d:\Jupiter\venv\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "УТВЕРЖДАЮ: Директор МКУ «ХЭУ АСР» __________ А.В. ..." with entities "[(1277, 1356, 'EC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# d:\Jupiter\venv\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Приложение № 4 к извещению Проект МУНИЦИПАЛЬНЫЙ КО..." with entities "[(1290, 1409, 'EC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# d:\Jupiter\venv\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "СОГЛАСОВАНО УТВЕРЖДЕНО И.о.начальника МКУ Директор..." with entities "[(1196, 1308, 'EC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# d:\Jupiter\venv\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "1 31 Приложение № 2 ПРОЕКТ КОНТРАКТА на организаци..." with entities "[(1243, 1355, 'EC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# d:\Jupiter\venv\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "ПРОЕКТ Контракт № _______________ Поставка хозяйст..." with entities "[(1261, 1384, 'EC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# d:\Jupiter\venv\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Утверждаю: Заведующий структурным подразделением Г..." with entities "[(1247, 1330, 'EC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# d:\Jupiter\venv\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "УТВЕРЖДАЮ Врио генерального директора ООО «ТСАХ» _..." with entities "[(1255, 1323, 'EC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# d:\Jupiter\venv\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "ЧАСТЬ II: Проект договора Запрос ценовых котировок..." with entities "[(1233, 1322, 'EC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# d:\Jupiter\venv\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "8 ПРОЕКТ Договор поставки товаров № ________ г. Ха..." with entities "[(1231, 1313, 'EC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# d:\Jupiter\venv\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "7 Договор поставки №______ г. Краснотурьинск «____..." with entities "[(1069, 1181, 'EC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# d:\Jupiter\venv\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "УТВЕРЖДАЮ Директор ГБУ «Жилищник Обручевского райо..." with entities "[(1070, 1170, 'EC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# d:\Jupiter\venv\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Проект муниципального контракта №_____ на выполнен..." with entities "[(1263, 1485, 'PWO')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# d:\Jupiter\venv\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "УТВЕРЖДАЮ Заказчик Главный врач ГБУЗ ООД Р.А. Зубк..." with entities "[(1147, 1318, 'PWO')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# d:\Jupiter\venv\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "9 Проект КОНТРАКТ № _______ Новосибирская область ..." with entities "[(1247, 1440, 'PWO')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# d:\Jupiter\venv\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Приложение №3 к извещению о проведении электронног..." with entities "[(1187, 1349, 'PWO')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# d:\Jupiter\venv\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Приложение к распоряжению администрации МО «Хараба..." with entities "[(1241, 1390, 'PWO')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# d:\Jupiter\venv\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Приложение №4 к извещению об осуществлении закупки..." with entities "[(1271, 1379, 'PWO')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# d:\Jupiter\venv\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "11 21 УТВЕРЖДАЮ Директор СПб ГБУ СОН «КЦСОН Фрунзе..." with entities "[(1215, 1376, 'PWO')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# d:\Jupiter\venv\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "14 МИНИСТЕРСТВО ЗДРАВООХРАНЕНИЯ РОССИЙСКОЙ ФЕДЕРАЦ..." with entities "[(1258, 1560, 'PWO')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# d:\Jupiter\venv\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Контракт ________________ «___» _________ ____ г. ..." with entities "[(1277, 1368, 'PWO')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# d:\Jupiter\venv\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Версия с 04.07.2022 года У Т В Е Р Ж Д А Ю «ГАУ РС..." with entities "[(1183, 1379, 'PWO')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# 1466
# d:\Jupiter\venv\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Информационная карта о проведении закупки с единст..." with entities "[(1246, 1413, 'PWO')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# d:\Jupiter\venv\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "«УТВЕРЖДАЮ» ______________/___________/ «__» _____..." with entities "[(1253, 1412, 'PWO')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# ('Извещение о проведении открытого конкурса в электронной форме для закупки №0328300032822000806 Общая информация Номер извещения 0328300032822000806 Наименование объекта закупки Поставка продуктов питания Способ определения поставщика (подрядчика, исполнителя) Открытый конкурс в бль Порядок внесения денежных средств в качестве обеспечения заявки на участие в закупке, а также условия гарантии Обеспечение заявки на участие в закупке может предоставляться участником закупки в виде денежных средств или независимой гарантии, предусмотренной ст. 45 Федерального закона № 44-ФЗ. Выбор способа обеспечения осуществляется участником закупки самостоятельно. Срок действия независимой гарантии должен составлять не менее месяца с даты окончания срока подачи заявок. Обеспечение заявки на участие в закупке предоставляется в соответствии с ч. 5 ст. 44 Федерального закона № 44-ФЗ. Условия независимой гарантии в соответствии со ст. 45 Федерального закона № 44-ФЗ. Реквизиты счета в соответствии с п.16 ч. 1 ст. 42 Закона № 44-ФЗ "Номер расчётного счёта" 00000000000000000000 "Номер лицевого счёта" См. прилагаемые документы "БИК" 000000000 "Наименование кредитной организации" "Номер корреспондентского счета" Обеспечение исполнения контракта Требуется обеспечение исполнения контракта Размер обеспечения исполнения контракта 6593.25 Российский рубль Порядок обеспечения исполнения контракта, требования к обеспечению Исполнение контракта, гарантийные обязательства могут обеспечиваться предоставлением независимой гарантии, соответствующей требованиям ст. 45 Федерального закона № 44-ФЗ, или внесением денежных средств на указанный заказчиком счет, на котором в соответствии с законодательством Российской Федерации учитываются операции со средствами, поступающими заказчику. Способ обеспечения исполнения контракта, гарантийных обязательств, срок действия независимой гарантии определяются в соответствии с требованиями Федерального закона № 44-ФЗ участником закупки, с которым заключается контракт, самостоятельно. При этом срок действия независимой гарантии должен превышать предусмотренный контрактом срок исполнения обязательств, которые должны быть обеспечены такой независимой гарантией, не менее чем на один месяц, в том числе в случае его изменения в соответствии со ст. 95 Федерального закона № 44-ФЗ. Порядок предоставления и требования о Информация и документы, подтверждающие соответствие участников закупки дополнительным требованиям: 1) исполненный договор; 2) акт приемки оказанных услуг и (или) поставленных товаров, подтверждающий цену оказанных услуг и (или) поставленных товаров 4',
#  {'entities': [(1279, 1343, 'EC')]})

# %% [markdown]
# ### Обучение модели Spacy

# %%
spacy.require_gpu()
print(spacy.prefer_gpu())
nlp = spacy.blank("ru")

ner = nlp.add_pipe("ner") # spancat

ner.add_label("обеспечение исполнения контракта")
ner.add_label("обеспечение гарантийных обязательств")

optimizer = nlp.begin_training()


for epoch in range(5):
    random.shuffle(data_train)
    loss = {}
    for batch in spacy.util.minibatch(data_train, size=2):
        example = None
        for text, annotations in batch:
            doc = nlp.make_doc(text)
            example = Example.from_dict(doc, annotations)

        nlp.update([example], sgd=optimizer, losses=loss, drop=0.2)
    print('Epoch: ',epoch, ' losses: ', loss)

#nlp.to_disk("model")

# %%
nlp = spacy.load('model_best')

# %%
nlp.pipe_names
# Out:
# ['ner']

# %%
analysis = nlp.analyze_pipes(pretty=True)
# Out:
# ============================= Pipeline Overview =============================
#
# #   Component   Assigns          Requires   Scores          Retokenizes
# -   ---------   --------------   --------   -------------   -----------
# 0   ner         doc.ents                    ents_f          False
#                 token.ent_iob               ents_p
#                 token.ent_type              ents_r
#                                             ents_per_type
#
# ✔ No problems found.

# %%
def accuracy(true, pred):
    true_pred = 0
    for i in range(len(true)):
        if true[i] == pred[i]:
            true_pred+=1
    return true_pred/len(true)

# %%
def create_true_pred_arr(data, model):
    data_true = []
    data_pred = []

    lengh_max_true = 0
    count = 0
    for i in range(len(data)):
        if data[i][1].get('entities'):
            left = data[i][1].get('entities')[0][0]
            right = data[i][1].get('entities')[0][1]
            text = data[i][0][left:right]
            data_true.append(text)
            label = data[i][1].get('entities')[0][2]
        else:
            text = ''
            label = ''
            data_true.append('')


        doc = model(data[i][0])
        if list(doc.ents):
            #if len(list(doc.ents)) > 2:
            ents = [ent.text for ent in doc.ents if ent.label_ == label]
            if ents:
                data_pred.append(str(max(ents, key=len)))
            else:
                data_pred.append('')
            #data_pred.append(str(doc.ents[0]))
        else:
            data_pred.append('')
        count+=1

    return data_true, data_pred

#data_true, data_pred = create_true_pred_arr(data_valid, nlp)
#print(len(data_true))
#print(len(data_pred))

# %%
def create_true_pred_arr_2(data, model):
    data_true = []
    data_pred = []

    lengh_max_true = 0
    count = 0
    for i in range(len(data)):
        if data[i][1].get('entities'):
            left = data[i][1].get('entities')[0][0]
            right = data[i][1].get('entities')[0][1]
            text = data[i][0][left:right]
            data_true.append(text)
            label = data[i][1].get('entities')[0][2]
        else:
            text = ''
            label = ''
            data_true.append('')


        doc = model(data[i][0])
        if list(doc.ents):
            #if len(list(doc.ents)) > 2:
            ents = [ent.text for ent in doc.ents if ent.label_ == label]
            if ents:
                pred = str(max(ents, key=len))

            else:
                pred = ''
                
        if pred != text:
            print('Нужно: ', text)
            print('Получил: ', ents, end='\n\n')


    return data_true, data_pred

#data_true, data_pred = create_true_pred_arr(data_valid, nlp)
#print(len(data_true))
#print(len(data_pred))

# %%
data_true, data_pred = create_true_pred_arr_2(data_train, nlp)
#print('Метрика accuracy на тренировочной выборке:', accuracy(data_true, data_pred))

#data_true, data_pred = create_true_pred_arr_2(data_valid, nlp)
#print('Метрика accuracy на тестовой выборке:', accuracy(data_true, data_pred))
# Out:
# Нужно:  Размер обеспечения исполнения контракта устанавливается в размере 5 (пять) процентов от цены, по которой заключается контракт и составляет ___
# Получил:  ['Участник закупки, с которым заключается контракт по результатам определения Поставщика в соответствии с п. 1 ч.1 ст.30 Закона № 44-ФЗ', 'Размер обеспечения исполнения контракта устанавливается в размере 5 (пять) процентов от цены, по которой заключается контракт']
#
# Нужно:  Размер обеспечения исполнения контракта (договора) составляет: 0,50% от цены
# Получил:  ['Размер обеспечения исполнения контракта (договора) составляет: 0,50% от цены, по которой в соответствии с Законом № 44-ФЗ заключается контракт.']
#
# Нужно:  Размер обеспечения исполнения контракта 5018.47 Российский рубль
# Получил:  ['Размер обеспечения исполнения контракта 5018.47 Российский рубль', 'Размер обеспечения исполнения Контракта составляет 10 % от начальной (максимальной) цены контракта.']
#
# Нужно:  Обеспечение исполнения настоящего Контракта установлено в размере 5,00% от цены контракта, а именно _______ рублей ____копеек.
# Получил:  ['Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта']
#
# Нужно:  Обеспечение исполнения Контракта устанавливается в размере 5 % от цены, по которой заключается Контракт, что составляет __
# Получил:  ['Обеспечение исполнения Контракта устанавливается в размере 5 % от цены, по которой заключается Контракт, что составляет __________руб. _____коп.']
#
# Нужно:  Обеспечение исполнения Контракта устанавливается в размере 0,5 % от цены Контракта, что составляет ___________ (____________
# Получил:  ['Обеспечение исполнения Контракта устанавливается в размере 0,5 % от цены Контракта, что составляет ___________ (____________) рублей ___ копеек.']
#
# Нужно:  Размер обеспечения исполнения контракта составляет 10% от цены контракта
# Получил:  ['Размер обеспечения исполнения контракта составляет 10% от цены контракта, по которой в соответствии с настоящим Федеральным законом заключается контракт.']
#
# Нужно:  Заказчиком установлено требование обеспечения исполнения контракта в размере 10 процентов от цены контракта, что составляет: ______________________
# Получил:  []
#
# Нужно:  Размер обеспечения исполнения Контракта составляет 5% (пять процентов) от цены Контракта, что составляет ___________ ( ) рублей
# Получил:  ['Размер обеспечения исполнения Контракта составляет 5% (пять процентов) от цены Контракта, что составляет ___________ ( ) рублей копеек.']
#
# Нужно:  Подрядчиком представлено обеспечение исполнения Контракта в виде _______________________________ в размере 10% от начальной (максимальной) цены Контракта
# Получил:  ['Размер обеспечения исполнения контракта 10.00%']
#
# Нужно:  Поставщик внес обеспечение исполнения Контракта в размере __ , что составляет 5 %
# Получил:  ['Поставщик внес обеспечение исполнения Контракта в размере __ , что составляет 5 % Цены Контракта в форме безотзывной независимой гарантии']
#
# Нужно:  Обеспечение исполнения Контракта составляет 10% от цены Контракта(цены лота),что составляет_________ (_____
# Получил:  ['Обеспечение исполнения Контракта составляет 10% от цены Контракта(цены лота),что составляет_________ (_________________________) рублей _____ копеек.']
#
# Нужно:  Поставщик при заключении Контракта должен предоставить Заказчику обеспечение исполнения Контракта в размере 5 % от цены
# Получил:  ['Поставщик при заключении Контракта должен предоставить Заказчику обеспечение исполнения Контракта в размере 5 % от цены, по которой в соответствии с Законом о контрактной системе заключается контракт']
#
# Нужно:  Обеспечение гарантийных обязательств устанавливается в размере 5% процентов начальной (максимальной) цены контракта, что составляет 60 787
# Получил:  ['Обеспечение гарантийных обязательств устанавливается в размере 5% процентов начальной (максимальной) цены контракта, что составляет 60 787 (шестьдесят тысяч семьсот восемьдесят семь) рублей 50 копеек.']
#
# Нужно:  таким участником обеспечения исполнения контракта в размере, превышающем в 1,5 раза размер обеспечения исполнения контракта, указанный в извещении, но не менее чем 10 процентов от начальной (максимальной) цены контракта
# Получил:  ['Размер обеспечения гарантийных обязательств 11599.38 Российский рубль']
#
# Нужно:  Размер обеспечения исполнения контракта 505.80 Российский рубль
# Получил:  ['Размер обеспечения исполнения контракта 505.80']
#
# Нужно:  Сумма обеспечения исполнения договора составляет 10 % цены Договора, что составляет __________ (_________________
# Получил:  ['Сумма обеспечения исполнения договора составляет 10 % цены Договора, что составляет __________ (___________________) рублей ___ копеек.']
#
# Нужно:  как участник предоставит обеспечение исполнения Контракта в размере, в 1,5 раза превышающем размер обеспечения исполнения Контракта, указанный в п. 7.1.1 Контракта, но не менее 10% от начальной (максимальной) цены Контракта
# Получил:  ['Размер обеспечения исполнения контракта 5.00%']
#
# Нужно:  предоставляет заказчику до подписания контракта обеспечение исполнения контракта в размере 5 % начальной (максимальной) цены контракта.
# Получил:  ['Размер обеспечения исполнения контракта 17120.00 Российский рубль']
#
# Нужно:  Обеспечение исполнения настоящего Контракта установлено в размере 5% от цены контракта и составляет _______ (___________________
# Получил:  ['Обеспечение исполнения настоящего Контракта установлено в размере 5% от цены контракта и составляет _______ (________________________________________) рублей ____ копеек.']
#
# Нужно:  Размер обеспечения исполнения контракта: 30% (тридцать процентов) от начальной (максимальной) це- ны контракта
# Получил:  ['Размер обеспечения исполнения контракта: 30% (тридцать процентов) от начальной (максимальной) це- ны контракта - 8 761 716 рублей 00 копеек.']
#
# Нужно:  Обеспечение исполнения Контракта устанавливается в размере 5% цены контракта, что составляет ____________ (_____________)
# Получил:  ['Обеспечение исполнения Контракта устанавливается в размере 5% цены контракта, что составляет ____________ (_____________) рублей ___ копеек.']
#
# Нужно:  Размер обеспечения исполнения Контракта устанавливается в размере 10 % от цены, по которой заключается Контракт и составляет______
# Получил:  ['Размер обеспечения исполнения Контракта устанавливается в размере 10 % от цены, по которой заключается Контракт и составляет____________ руб. ___ коп.']
#
# Нужно:  Размер обеспечения исполнения контракта 5% от цены контракта
# Получил:  ['Размер обеспечения исполнения контракта 5% от цены контракта 21.']
#
# Нужно:  Размер обеспечения исполнения контракта 5% от цены контракта
# Получил:  ['Размер обеспечения исполнения контракта 5% от цены контракта 21.']
#
# Нужно:  Обеспечение исполнения настоящего Контракта устанавливается в размере 1 процент от начальной (максимальной) цены Контракта и составляет ___
# Получил:  ['Размер обеспечения исполнения контракта: 5 % от цены контракта.']
#
# Нужно:  Заказчиком установлено требование обеспечения исполнения Контракта - 5 % от цены Контракта, что составляет ​​​​​​​​​​​_____________
# Получил:  []
#
# Нужно:  Обеспечение исполнения Контракта устанавливается в размере - 1 % от цены Контракта
# Получил:  ['Обеспечение исполнения Контракта устанавливается в размере - 1 % от цены Контракта, в соответствии с частями 6 -']
#
# Нужно:  Размер обеспечения исполнения Контракта составляет 5% от цены Контракта.
# Получил:  ['Обеспечение исполнения настоящего Контракта по выбору Исполнителя предоставляется в форме независимой гарантии', 'Размер обеспечения исполнения Контракта составляет 5% от цены Контракта.']
#
# Нужно:  Обеспечение исполнения Контракта устанавливается в размере 10 % (десять процентов) от цены контракта
# Получил:  ['Обеспечение исполнения Контракта устанавливается в размере 10 % (десять процентов) от цены контракта, по которой в соответствии с Законом № 44-ФЗ заключается контракт.']
#
# Нужно:  обеспечения исполнения контракта в размере, превышающем в 1,5 раза размер обеспечения исполнения контракта, указанный в извещении, но не менее чем 10 процентов от начальной (максимальной) цены контракта или от цены
# Получил:  ['Поставщик при заключении Контракта должен предоставить Заказчику обеспечение исполнения Контракта в размере 5 % начальной (максимальной) цены Контракта']
#
# Нужно:  Обеспечение исполнения Контракта предоставляется в размере 10 % начальной (максимальной) цены государственного контракта.
# Получил:  ['Поставщик до заключения Контракта предоставляет Заказчику обеспечение исполнения Контракта в соответствии со статьей 96 Федерального закона о контрактной системе.']
#
# Нужно:  Обеспечение исполнения настоящего Контракта устанавливается в размере 10 (десяти) процентов от цены НМЦК и составляет __________ (___________) руб. _
# Получил:  ['Обеспечение исполнения настоящего Контракта устанавливается в размере 10 (десяти) процентов от цены НМЦК и составляет __________ (___________) руб. _____ коп.']
#
# Нужно:  Участник закупки, с которым заключается договор, обязан представить обеспечение исполнения договора в размере 5% от цены
# Получил:  ['Участник закупки, с которым заключается договор, обязан представить обеспечение исполнения договора в размере 5% от цены, по которой в соответствии с Законом заключается контракт.']
#
# Нужно:  Обеспечение исполнения Контракта установлено в размере 10 (десять) % от цены, по которой заключается Контракт, что составляет __
# Получил:  ['Обеспечение исполнения Контракта установлено в размере 10 (десять) % от цены, по которой заключается Контракт, что составляет ____________________.']
#
# Нужно:  Размер обеспечения исполнения Контракта составляет 5% (пять процентов) от цены Контракта, что составляет _____рублей ____копеек
# Получил:  ['Размер обеспечения исполнения Контракта составляет 5% (пять процентов) от цены Контракта, что составляет _____рублей ____копеек.']
#
# Нужно:  Размер обеспечения исполнения контракта составляет 5% (десять процентов) от цены контракта, что составляет _______ рублей 00
# Получил:  ['Размер обеспечения исполнения контракта составляет 5% (десять процентов) от цены контракта, что составляет _______ рублей 00 копеек.']
#
# Нужно:  Размер обеспечения исполнения контракта 5 % от цены
# Получил:  ['Размер обеспечения исполнения контракта 5 % от цены, по которой в соответствии с Федеральным законом заключается контракт']
#
# Нужно:  Обеспечение исполнения настоящего Контракта устанавливается в размере 5 (пяти) процентов от цены Контракта и составляет ______ (__________________
# Получил:  ['Обеспечение исполнения настоящего Контракта устанавливается в размере 5 (пяти) процентов от цены Контракта и составляет ______ (_____________________) руб. ___коп.']
#
# Нужно:  Обеспечение исполнения Контракта устанавливается в размере 5 % (Пять) от цены Контракта
# Получил:  ['Обеспечение исполнения Контракта устанавливается в размере 5 % (Пять) от цены Контракта, по которой в соответствии с Федеральным законом № 44-ФЗ заключается контракт.']
#
# Нужно:  Установить обеспечения исполнения контракта (от 0,5% до 30%) % обеспечения
# Получил:  ['Размер обеспечения: 18 Установить обеспечение гарантийных обязательств (Не более 10 %) Не установлено']
#
# Нужно:  Обеспечение гарантийных обязательств 5% от НМЦК.
# Получил:  ['Обеспечение гарантийных обязательств 5% от НМЦК.', 'Размер обеспечения гарантийных обязательств 160000.00 Российский рубль']
#
# Нужно:  Размер обеспечения исполнения контракта 10% от цены контракта
# Получил:  ['Требование обеспечения исполнения контракта УСТАНОВЛЕНО https://internet.garant.ru/#/document/12122754/entry/0 https://internet.garant.ru/#/document/70353464/entry/45', 'Размер обеспечения исполнения контракта 10% от цены контракта']
#
# Нужно:  Поставщик при заключении Контракта должен предоставить Заказчику обеспечение исполнения Контракта в размере ___ , что составляет 5 % цены Контракта
# Получил:  ['Поставщик при заключении Контракта должен предоставить Заказчику обеспечение исполнения Контракта в размере ___ , что составляет 5 % цены Контракта, в случае если предложенная Поставщиком цена Контракта снижена на 25% и более, но не менее 10 % от цены Контракта, обеспечение исполнения Контракта предоставляется в соответствиисо статьей 37 Федерального закона о контрактной системе.']
#
# Нужно:  Размер обеспечения исполнения контракта составляет 5 % от начальной (максимальной) цены контракта.
# Получил:  ['В обеспечение исполнения контракта поставщик предоставляет заказчику независимую гарантию соответствующую требованиям ст. 45 Федерального закона от 05.04.2013 г. № 44-ФЗ', 'Размер обеспечения исполнения контракта составляет 5 % от начальной (максимальной) цены контракта.']
#
# Нужно:  Размер обеспечения исполнения Контракта составляет 5 (пять) процентов от цены Контракта и составляет ____________ руб. ________
# Получил:  ['Размер обеспечения исполнения Контракта составляет 5 (пять) процентов от цены Контракта и составляет ____________ руб. __________ коп.']
#
# Нужно:  Обеспечение исполнения контракта устанавливается в размере 5 % от цены
# Получил:  ['Обеспечение исполнения контракта устанавливается в размере 5 % от цены, по которой в соответствии с Федеральным законом № 44-ФЗ заключается контракт.']
#
# Нужно:  Размер обеспечения исполнения контракта составляет 5,00% от цены, по которой в соответствии с Федеральным законом
# Получил:  ['Размер обеспечения исполнения контракта составляет 5,00% от цены, по которой в соответствии с Федеральным законом от 05.04.2013 года №44-ФЗ заключается контракт _______ (____________) рублей __ копеек.', 'Участник закупки, с которым заключается контракт по результатам определения поставщика (подрядчика, исполнителя) в соответствии с пунктом 1 части 1 статьи 30 Федерального закона от 05.04.2013 года №44-ФЗ']
#
# Нужно:  Размер обеспечения исполнения Контракта составляет 30% начальной (максимальной) цены Контракта, что составляет ___
# Получил:  ['Размер обеспечения исполнения Контракта составляет 30% начальной (максимальной) цены Контракта']
#
# Нужно:  Размер обеспечения исполнения Контракта составляет 30% начальной (максимальной) цены Контракта, что составляет ___
# Получил:  ['Размер обеспечения исполнения Контракта составляет 30% начальной (максимальной) цены Контракта']
#
# Нужно:  Размер обеспечения исполнения контракта составляет 5,00% от начальной цены контракта, что составляет 42 500,00
# Получил:  ['Размер обеспечения исполнения контракта', 'Размер обеспечения исполнения контракта составляет 5,00% от начальной цены контракта']
#
# Нужно:  Обеспечение исполнения настоящего Контракта установлено в размере 5% от цены Контракта в сумме ________________________ (_______
# Получил:  ['Обеспечение исполнения настоящего Контракта установлено в размере 5% от цены Контракта в сумме ________________________ (_____________________________) рублей ___ копеек.']
#
# Нужно:  Размер обеспечения исполнения контракта 5 % от цены
# Получил:  ['Размер обеспечения исполнения контракта 5 % от цены, по которой в соответствии с Федеральным законом заключается контракт']
#
# Нужно:  Размер обеспечения исполнения Контракта составляет 20 % от цены Контракта, что составляет _________
# Получил:  ['Размер обеспечения исполнения Контракта составляет 20 % от цены Контракта, что составляет _________ (сумма прописью) рублей ___ копеек.']
#
# Нужно:  Обеспечение исполнения настоящего Контракта установлено в размере 10 (десять) процентов от цены контракта, а именно _________ рублей
# Получил:  ['Обеспечение исполнения настоящего Контракта установлено в размере 10 (десять) процентов от цены контракта, а именно _________ рублей (__________________)']
#
# Нужно:  Размер обеспечения исполнения Контракта составляет 5% от цены Контракта.
# Получил:  ['Обеспечение исполнения настоящего Контракта по выбору Исполнителя предоставляется в форме независимой гарантии', 'Размер обеспечения исполнения Контракта составляет 5% от цены Контракта.']
#
# Нужно:  Обеспечение исполнения настоящего Контракта установлено в размере 0,5% от цены Контракта и составляет ____ (____ рублей __ коп.).
# Получил:  ['Обеспечение исполнения настоящего Контракта установлено в размере 0,5% от цены Контракта и составляет ____ (____ рублей __ коп.']
#
# Нужно:  Размер обеспечения исполнения Контракта составляет 5% (пять процентов) цены контракта, что составляет _______________ руб.
# Получил:  ['Размер обеспечения исполнения Контракта составляет 5% (пять процентов) цены контракта']
#
# Нужно:  Размер обеспечения исполнения Контракта составляет 10% (десять процентов) от цены Контракта, что составляет ____ (__________)
# Получил:  ['Размер обеспечения исполнения Контракта составляет 10% (десять процентов) от цены Контракта, что составляет ____ (__________) рублей ____ копеек.']
#
# Нужно:  Подрядчик представляет Заказчику обеспечение исполнения Контракта в виде _______________ в размере 10% от ______________, что составляет _________________________
# Получил:  ['Размер обеспечения исполнения контракта 5.00%']
#
# Нужно:  Обеспечение исполнения Контракта установлено в размере 5 % от цены Контракта, что составляет _____________ рублей
# Получил:  ['Обеспечение исполнения Контракта установлено в размере 5 % от цены Контракта, что составляет _____________ рублей __ копеек.']
#
# Нужно:  Обеспечение исполнения настоящего Контракта предоставляется в размере 1% от цены контракта
# Получил:  ['Обеспечение исполнения настоящего Контракта предоставляется в размере 1% от цены контракта, что составляет _________ рублей.']
#
# Нужно:  Обеспечение исполнения настоящего Контракта предоставляется в размере 1% от цены контракта
# Получил:  ['Обеспечение исполнения настоящего Контракта предоставляется в размере 1% от цены контракта, что составляет _________ рублей.']
#
# Нужно:  Размер обеспечения исполнения Контракта 50 % от цены контракта, что составляет ________________________
# Получил:  ['Размер обеспечения исполнения Контракта 50 % от цены контракта, что составляет ________________________ руб.']
#
# Нужно:  Размер обеспечения исполнения настоящего Контракта составляет 5 процентов цены Контракта.
# Получил:  ['Размер обеспечения исполнения настоящего Контракта составляет 5 процентов цены Контракта.', 'Участник закупки, с которым заключается контракт по результатам определения поставщика (подрядчика, исполнителя) в соответствии с пунктом 1 части 1 статьи 30 Федерального закона от 05.04.2013 № 44-ФЗ']
#
# Нужно:  Обеспечение исполнения Контракта устанавливается в размере 10 % цены Контракта и составляет ___________
# Получил:  ['Обеспечение исполнения Контракта устанавливается в размере 10 % цены Контракта и составляет ___________ (сумма прописью) руб. __ коп.[footnoteRef:1]']
#
# Нужно:  требования к такому обеспечению 10 % начальной (максимальной) цены контракта и составляет 184 759,70 рублей.
# Получил:  []
#
# Нужно:  Обеспечение исполнения Контракта предоставляется в размере 10 % от цены Контракта в сумме________
# Получил:  ['Обеспечение исполнения настоящего Контракта установлено в размере 745,47, эквивалентную 0,50 % от начальной (максимальной) цены контракта.']
#
# Нужно:  Размер обеспечения исполнения контракта (договора) составляет: 5,00% от цены
# Получил:  ['Размер обеспечения исполнения контракта 10.00%']
#
# Нужно:  Обеспечение исполнения Контракта устанавливается в размере 0,50% от цены контракта.
# Получил:  ['Обеспечение исполнения Контракта устанавливается в размере 0,50% от цены контракта.', 'Размер обеспечения исполнения Контракта в ходе исполнения Контракта подлежит уменьшению в порядке и случаях, которые предусмотрены пунктами 7.6 и 7.7 Контракта.']
#
# Нужно:  Обеспечение исполнения Контракта устанавливается в размере 5% от цены Контракта и составляет ________ (__________) руб. _
# Получил:  ['Обеспечение исполнения Контракта устанавливается в размере 5% от цены Контракта и составляет ________ (__________) руб. ______коп.']
#
# Нужно:  Договор заключается после предоставления Поставщиком, обеспечения исполнения Договора в размере 5 % от начальной (максимальной) цены Договора
# Получил:  ['Обеспечение исполнения договора: 5% от начальной (максимальной) цены договора: 11 438,00 руб.']
#
# Нужно:  Размер обеспечения исполнения договора составляет 3 % начальной (максимальной) цены договора ________ рублей.
# Получил:  ['Размер обеспечения исполнения договора составляет 3 % начальной (максимальной) цены договора']
#
# Нужно:  обеспечение исполнения договора в размере не менее 5.00 % от цены договора
# Получил:  ['обеспечение исполнения договора в размере не менее 5.00 % от цены договора 1.']
#
# Нужно:  Обеспечение исполнения договора 1% от начальной максимальной цены договора : 18 564, 00 рублей (Восемнадцать тысяч пятьсот шестьдесят четыре рубля 00
# Получил:  ['Обеспечение исполнения договора 1% от начальной максимальной цены договора : 18 564, 00 рублей (']
#
# Нужно:  Участник Конкурса, с которым заключается договор должен предоставить обеспечение исполнения договора в размере 11 000 000,00 руб. 5% от начальной (максимальной) цены договора
# Получил:  ['Обеспечение исполнения договора 1% от начальной максимальной цены договора : 18 564, 00 рублей (']
#
# Нужно:  обеспечения исполнения договора в размере, превышающем в полтора раза размер обеспечения исполнения договора, указанный в документации о закупке, но не менее, чем 10 (десять) процентов от начальной (максимальной) цены договора;
# Получил:  ['В целях обеспечения исполнения обязательств Поставщика по настоящему Договору', 'обеспечение исполнения настоящего Договора).', 'Размер обеспечения исполнения договора составляет 5% начальной (максимальной) цены договора']
#
# Нужно:  Размер обеспечения исполнения Контракта 5 % от начальной максимальной цены Контракта
# Получил:  ['Размер обеспечения исполнения Контракта 5 % от начальной максимальной цены Контракта 25 Срок обеспечения исполнения Контракта Со дня заключения договора до полного исполнения контракта (срок действия независимой гарантии превышающий срок действия контракта не менее чем на один месяц)']
#
# Нужно:  Сумма обеспечения настоящего Договора составляет: 240 000,00 рублей.
# Получил:  ['Сумма обеспечения настоящего Договора составляет: 240 000,00 рублей.', 'Обеспечение исполнения настоящего Договора по выбору Поставщика предоставляется в форме банковской гарантии']
#
# Нужно:  такой участник обязан предоставить обеспечение исполнения договора в размере 5 процентов от начальной (максимальной) цены договора (цены лота)
# Получил:  ['Размер обеспечения исполнения договора составляет 5% от начальной (максимальной) цены договора']
#
# Нужно:  Размер обеспечения исполнения договора 5% (пять) процентов от начальной (максимальной) цены договора – 4 859,00
# Получил:  ['Размер обеспечения исполнения договора 5% (пять) процентов от начальной (максимальной) цены договора']
#
# Нужно:  Обеспечение исполнения настоящего договора предоставляется Поставщиком в размере: 5 % от начальной (максимальной) цены договора в сумме 7501,66
# Получил:  ['Обеспечение исполнения настоящего договора предоставляется Поставщиком в размере: 5 % от начальной (максимальной) цены договора']
#
# Нужно:  При проведении закупок по группе 2 Заказчик имеет право устанавливать обеспечение исполнения договора в размере: 1) не более 5% от начальной (максимальной) цены договора (лота)
# Получил:  ['Если в документации о закупке Заказчиком установлено требование к обеспечению исполнения договора, такое обеспечение может предоставляться участником закупки по его выбору путем внесения денежных средств']
#
# Нужно:  Предусмотрено обеспечение исполнения договора в размере 5% начальной (максимальной) цены договора: 2 039 рублей 32
# Получил:  ['Предусмотрено обеспечение исполнения договора в размере 5% начальной (максимальной) цены договора: 2 039 рублей 32 копейки.']
#
# Нужно:  Поставщик при заключении договора должен предоставить Заказчику обеспечение исполнения договора в размере 5 % начальной (максимальной) цены договора, что составляет ____
# Получил:  ['Поставщик при заключении договора должен предоставить Заказчику обеспечение исполнения договора в размере 5 % начальной (максимальной) цены договора']
#
# Нужно:  Размер обеспечения исполнения Договора, условия, порядок и форма внесения обеспечения исполнения Договора 5 % от начальной (максимальной) цены Договора: 13 804 рубля 52 копейки.
# Получил:  ['Размер обеспечения исполнения договора: 10 % от начальной (максимальной) цены договора']
#
# Нужно:  Обеспечение исполнения настоящего договора предоставляется поставщиком в размере: 3% начальной (максимальной) цены договора на сумму 5 826,80
# Получил:  ['Обеспечение исполнения настоящего договора предоставляется поставщиком в размере: 3% начальной (максимальной) цены договора']
#
# Нужно:  Размер обеспечения исполнения Договора, условия, порядок и форма внесения обеспечения исполнения Договора 5 % от начальной (максимальной) цены Договора: 41 103 рубля 78 копеек
# Получил:  ['Размер обеспечения исполнения договора – 5 % начальной (максимальной) цены договора.']
#
# Нужно:  Размер обеспечения исполнения Договора составляет 5% от начальной максимальной цены Договора 123 810,00 руб.
# Получил:  ['Размер обеспечения исполнения Договора составляет 5% от начальной максимальной цены Договора 123 810,00 руб. (сто двадцать три тысячи восемьсот десять рублей, 00 копеек)']
#
# Нужно:  Обеспечение исполнения договора 10% (десять процентов) от начальной (максимальной) цены договора (лота)
# Получил:  ['Обеспечение исполнения договора 10% (десять процентов) от начальной (максимальной) цены договора (лота) –– 104 340,72 рублей, НДС не облагается.']
#
# Нужно:  Заказчик вправе установить в документации о закупке требование к обеспечению исполнения договора в размере не более 5 (пяти) процентов от начальной (максимальной) цены договора с НДС
# Получил:  ['Заказчик вправе установить в документации о закупке требование к обеспечению исполнения договора в размере не более 5 (пяти) процентов от начальной (максимальной) цены договора']
#
# Нужно:  Обеспечение исполнения договора составляет: 5 % начальной (максимальной) цены договора, НДС не облагается.
# Получил:  ['Обеспечение исполнения договора составляет: 5 % начальной (максимальной) цены договора']
#
# Нужно:  В случае если Поставщиком, при участии в закупке, дано предложение с признаками демпинга, то обеспечение исполнения Договора составляет 5 % (пяти) процентов начальной (максимальной) цены Договора)
# Получил:  ['Сумма обеспечения исполнения договора предусмотрена в следующем размере: 5 % от начальной (максимальной) цены договора']
#
# Нужно:  В случае если Поставщиком, при участии в закупке, дано предложение с признаками демпинга, то обеспечение исполнения Договора составляет 5 % (пяти) процентов начальной (максимальной) цены Договора)
# Получил:  ['Сумма обеспечения исполнения договора предусмотрена в следующем размере: 5 % от начальной (максимальной) цены договора']
#
# Нужно:  Поставщик предоставляет обеспечение исполнения договора в размере 2 (два) % от начальной (максимальной) цены договора
# Получил:  ['Если требование о предоставлении обеспечения исполнения договора установлено извещением и документацией о проведении запроса котировок']
#
# Нужно:  размер обеспечения исполнения договора 10% от начальной максимальной цены договора
# Получил:  ['Заказчиком установлено требование обеспечения исполнения договора, исполнения гарантийных обязательств', 'Размер обеспечения исполнения гарантийных обязательств не может превышать 2 % начальной (максимальной) цены договора (цены лота).']
#
# Нужно:  обеспечения исполнения договора в размере, превышающем в полтора раза размер обеспечения исполнения договора, указанный в документации о закупке, но не менее, чем 10 (десять) процентов от начальной (максимальной) цены договора;
# Получил:  ['Заказчиком установлено требование обеспечения исполнения договора, исполнения гарантийных обязательств', 'Размер обеспечения исполнения гарантийных обязательств не может превышать 2 % начальной (максимальной) цены договора (цены лота).']
#
# Нужно:  Обеспечение исполнения договора представляется в размере 10% от начальной (максимальной) цены договора в сумме________
# Получил:  ['Обеспечение исполнения договора представляется в размере 10% от начальной (максимальной) цены договора']
#
# Нужно:  Поставщик/Исполнитель, в соответствии с закупочной документацией предоставляет Заказчику обеспечение исполнения договора в размере 5% (или 7,5 % при снижении сцены договора на 25 % и более) от начальной (максимальной) цены договора
# Получил:  ['Обеспечение исполнения договора:', 'Размер обеспечения исполнения договора составляет 5% от итоговой цены договора.']
#
# Нужно:  Обеспечение исполнения договора устанавливается в размере 5 % от цены договора
# Получил:  ['Обеспечение исполнения договора устанавливается в размере 5 % от цены договора, заключаемого по результатам проведенного аукциона в электронной форме.']
#
# Нужно:  Обеспечение исполнения договора устанавливается в размере 5 % от цены договора
# Получил:  ['Обеспечение исполнения договора устанавливается в размере 5 % от цены договора, заключаемого по результатам проведенного аукциона в электронной форме.']
#
# Нужно:  Сумма обеспечительного платежа, предоставляемого в качестве обеспечения гарантийных обязательств по договору, должна составлять 5% от цены договора (включая НДС).
# Получил:  ['Размер обеспечения исполнения договора', 'Обеспечение исполнения обязательств по Договору устанавливается в размере 5 (пяти) процентов от начальной (максимальной) цены Договора']
#
# Нужно:  Заказчиком установлено требование обеспечения исполнения договора и (или) обеспечения исполнения гарантийных обязательств 5% от начальной (максимальной) цены договора, что составляет 89 649
# Получил:  ['Заказчиком установлено требование обеспечения исполнения договора и (или) обеспечения исполнения гарантийных обязательств 5% от начальной (максимальной) цены договора, что составляет 89 649 (Восемьдесят девять тысяч шестьсот сорок девять) рублей 48 копеек в форме независимой гарантии']
#
# Нужно:  Размер обеспечения исполнения договора 5 % от начальной максимальной цены договора – 266 500 рублей
# Получил:  ['Размер обеспечения исполнения договора 5 % от начальной максимальной цены договора']
#
# Нужно:  Сумма обеспечения исполнения Договора предоставляется в размере 5 % от начальной (максимальной) цены договора Н(М)ЦД
# Получил:  ['Сумма обеспечения исполнения Договора предоставляется в размере 5 % от начальной (максимальной) цены договора Н(М)ЦД - 16 650,00 руб. (Шестнадцать тысяч шестьсот пятьдесят рублей 00 копеек).']
#
# Нужно:  Сумма обеспечения исполнения Договора предоставляется в размере 5 % от начальной (максимальной) цены договора Н(М)ЦД
# Получил:  ['Сумма обеспечения исполнения Договора предоставляется в размере 5 % от начальной (максимальной) цены договора Н(М)ЦД - 16 650,00 руб. (Шестнадцать тысяч шестьсот пятьдесят рублей 00 копеек).']
#
# Нужно:  Обеспечение исполнения договора 5% от начальной максимальной цены договора
# Получил:  ['Обеспечение исполнения договора 5% от начальной максимальной цены договора 5 372 (Пять тысяч триста семьдесят два) рубля 00 копеек.']
#
# Нужно:  Принять к сведению, что Исполнитель внес обеспечение исполнения Договора на сумму 30 000,00 (тридцать тысяч) рублей 00 копеек, что составляет 10% от начальной (максимальной)
# Получил:  ['Принять к сведению, что Исполнитель внес обеспечение исполнения Договора на сумму 30 000,00 (тридцать тысяч) рублей 00 копеек, что составляет 10% от начальной (максимальной) цены Договора']
#
# Нужно:  Форма, размер и условия обеспечения исполнения договора Установлено 5 % от начальной (максимальной) цены договора.
# Получил:  ['Сумма обеспечения исполнения договора предусмотрена в следующем размере: 5 % от начальной (максимальной) цены договора']
#
# Нужно:  Обеспечение исполнения договора предоставляется на сумму 100 000,00 (Сто тысяч рублей 00 копеек), что составляет 5%
# Получил:  ['В целях обеспечения исполнения обязательств по настоящему договору Исполнитель обязуется оформить и предоставить Заказчику безотзывную банковскую гарантию']
#
# Нужно:  Размер обеспечения исполнения договора 5 % от начальной (максимальной) цены.
# Получил:  ['Размер обеспечения исполнения договора 5 % от начальной (максимальной) цены.', 'Сумма обеспечения исполнения договора составляет 30384,26 (тридцать тысяч триста восемьдесят четыре рубля двадцать шесть копеек.)']
#
# Нужно:  Участник-победитель (далее Поставщик) вносит обеспечение исполнения Договора в размере 3% от начальной (максимальной) цены договора
# Получил:  ['Обеспечение исполнения договора: Устанавливается.']
#
# Нужно:  обеспечение исполнения обязательств по Договору на сумму не менее 20% от стоимости Договора с учетом НДС по форме Приложения №11
# Получил:  ['обеспечение исполнения обязательств по Договору на сумму не менее 20% от стоимости Договора с учетом НДС по форме Приложения №11 к настоящему Договору со сроком действия до 31.08.2025г., но не ранее января 2024 года.']
#
# Нужно:  обеспечение исполнения обязательств по Договору на сумму не менее 20% от стоимости Договора с учетом НДС по форме Приложения №11
# Получил:  ['обеспечение исполнения обязательств по Договору на сумму не менее 20% от стоимости Договора с учетом НДС по форме Приложения №11 к настоящему Договору, со сроком действия до 31.08.2025 г., но не ранее января 2024 года.']
#
# Нужно:  обеспечение исполнения обязательств по Договору на сумму не менее 20% от стоимости Договора с учетом НДС по форме Приложения №11
# Получил:  ['обеспечение исполнения обязательств по Договору на сумму не менее 20% от стоимости Договора с учетом НДС по форме Приложения №11 к настоящему Дого- вору со сроком действия до 31.08.2025г., но не ранее января 2024 года.']
#
# Нужно:  в соответствии с пп. 25,26 Постановления Правительства РФ от 11.12.2014 № 1352 требование к обеспечению исполнения договора не может превышать 5% от стоимости договора.
# Получил:  ['Размер обеспечения исполнения договора: 5% НМЦД']
#
# Нужно:  не предусмотрено увеличенное от первоначально установленного обеспечения исполнения договора в 1,5 (полтора) раза, но не более 5% (пяти) от начальной (максимальной) цены договора
# Получил:  ['не предусмотрено увеличенное от первоначально установленного обеспечения исполнения договора в 1,5 (полтора) раза, но не более 5% (пяти) от начальной (максимальной) цены договора (цены лота)']
#
# Нужно:  Обеспечение исполнения договора (30%)
# Получил:  ['Обеспечение исполнения договора (30%) может быть предоставлено:: - в виде безотзывной банковской гарантии (рекомендуемый образец –']
#
# Нужно:  Обеспечение исполнения договора 5% от НМЦД – 6 500,00 рублей.
# Получил:  ['Обеспечение исполнения договора 5% от НМЦД']
#
# Нужно:  Размер и порядок предоставления обеспечения исполнения договора, а также требования к такому обеспечению 5 % от начальной (максимальной) цены договора. 18 994,35 руб.
# Получил:  ['Размер обеспечения исполнения договора устанавливается в размере 5 % от начальной (максимальной) цены договора']
#
# Нужно:  к такому участнику применяется требование об обеспечении исполнения договора в размере 30% (тридцати процентов) от начальной (максимальной) цены договора без учета НДС
# Получил:  ['к такому участнику применяется требование об обеспечении исполнения договора в размере 30% (тридцати процентов) от начальной (максимальной) цены договора без учета НДС, что составляет 25 809,00 (двадцать пять тысяч восемьсот девять) рублей 00 копеек.']
#
# Нужно:  к такому участнику применяется требование об обеспечении исполнения договора в размере 30% (тридцати процентов) от начальной (максимальной) цены договора без учета НДС
# Получил:  ['к такому участнику применяется требование об обеспечении исполнения договора в размере 30% (тридцати процентов) от начальной (максимальной) цены договора без учета НДС, что составляет 25 809,00 (двадцать пять тысяч восемьсот девять) рублей 00 копеек.']
#
# Нужно:  Обеспечение исполнения договора в размере не менее 5% от цены договора
# Получил:  ['Обеспечение исполнения обязательств по договору:', 'Обеспечение исполнения договора в размере не менее 5% от цены договора должно быть предоставлено в срок не более 20 (двадцати) дней']
#
# Нужно:  Размер обеспечения исполнения договора, руб. 32 550,00
# Получил:  ['Обеспечение исполнения обязательств по договору:', 'Обеспечение исполнения договора в размере не менее 5% от цены договора должно быть предоставлено в срок не более 20 (двадцати) дней']
#
# Нужно:  такой участник обязан предоставить обеспечение исполнения договора в размере 5 процентов от начальной (максимальной) цены договора (цены лота)
# Получил:  ['Поставщик до заключения Договора предоставляет Заказчику обеспечение исполнения Договора в размере 5% Начальной максимальной цены Договора']
#
# Нужно:  Обеспечение исполнения Договора составляет 5 % от начальной (максимальной) цены Договора в сумме _________
# Получил:  ['Обеспечение исполнения Договора составляет 5 % от начальной (максимальной) цены Договора']
#
# Нужно:  договор заключается только после предоставления таким участником обеспечения исполнения договора в размере 25% начальной (максимальной) цены договора
# Получил:  ['Обеспечение исполнения гарантийных обязательств по договору устанавливается в размере 2% начальной (максимальной) цены договора и составляет 19 207,49 рубля.']
#
# Нужно:  вправе потребовать предоставление таким участником обеспечения договора в размере 5 процентов от начальной максимальной цены договора
# Получил:  ['не предусмотрено увеличенное от первоначально установленного обеспечения исполнения договора в 1,5 (полтора) раза, но не менее 5% (пяти) от НМЦ']
#
# Нужно:  договор заключается только после предоставления таким участником обеспечения исполнения договора в размере 25% начальной (максимальной) цены договора
# Получил:  ['Размер обеспечения исполнения договора: 5 % от начальной (максимальной) цены договора']
#
# Нужно:  Обеспечение исполнения договора 5% от начальной (максимальной) цены договора
# Получил:  ['Размер обеспечения исполнения Договора установлен заказчиком в размере 5% от начальной максимальной цены']
#
# Нужно:  Размер обеспечения исполнения обязательств по договору может устанавливается в размере до 30% НМЦД с учетом НДС
# Получил:  ['Форма обеспечения исполнения обязательств по договору устанавливается в документации о закупке в пп.23 п 4.4.', 'Размер обеспечения исполнения обязательств по договору может устанавливается в размере до 30% НМЦД']
#
# Нужно:  размер обеспечения договора не может превышать 5 процентов начальной максимальной цены договора
# Получил:  ['Форма обеспечения исполнения обязательств по договору устанавливается в документации о закупке в пп.23 п 4.4.', 'Размер обеспечения исполнения обязательств по договору может устанавливается в размере до 30% НМЦД']
#
# Нужно:  Обеспечение исполнения настоящего Договора установлено в размере 5% от начальной (максимальной) цены
# Получил:  ['Обеспечение исполнения настоящего Договора установлено в размере 5% от начальной (максимальной) цены, установленной Извещением и Документацией о проведении Аукциона в электронной форме участниками, которого могут быть только субъекты малого и среднего предпринимательства, и составляет - ___________ (________________) рублей __ копеек.']
#
# Нужно:  договор заключается только после предоставления таким участником обеспечения исполнения договора в размере 25% начальной (максимальной) цены договора
# Получил:  ['Обеспечение исполнения настоящего Договора установлено в размере 5% от начальной (максимальной) цены, установленной Извещением и Документацией о проведении Аукциона в электронной форме участниками, которого могут быть только субъекты малого и среднего предпринимательства, и составляет - ___________ (________________) рублей __ копеек.']
#
# Нужно:  Размер предоставленного до даты заключения настоящего Договора обеспечения исполнения Договора составляет 5% (пять процентов) от цены Договора в сумме ____________________ руб.
# Получил:  ['Размер предоставленного до даты заключения настоящего Договора обеспечения исполнения Договора составляет 5% (пять процентов) от цены Договора в сумме ____________________ руб. (_________________________________ руб. _______коп.)']
#
# Нужно:  Размер обеспечения исполнения договора составляет 5 % максимальной цены договора и установлен в сумме 49 775 руб.
# Получил:  ['Размер обеспечения исполнения договора составляет 5 % максимальной цены договора']
#
# Нужно:  Обеспечение исполнения Договора представляется в размере 5% начальной (максимальной) цены договора, что составляет ____
# Получил:  ['Обеспечение исполнения Договора представляется в размере 5% начальной (максимальной) цены договора']
#
# Нужно:  Обеспечение исполнения договора 5 % от начальной (максимальной) цены договора
# Получил:  ['Обеспечение исполнения договора предусмотрено в размере 5% от начальной (максимальной) цены договора']
#
# Нужно:  Размер обеспечения исполнения договора составляет 5% (пять процентов) от цены Договора.
# Получил:  ['Размер обеспечения исполнения Договора составляет 5%: Проценты на сумму обеспечительного платежа не начисляются.']
#
# Нужно:  Обеспечение исполнения договора 10% (десять процентов) от начальной (максимальной) цены договора (лота)
# Получил:  ['Обеспечение исполнения договора 10% (десять процентов) от начальной (максимальной) цены договора (лота) –– 160 575,62 рублей']
#
# Нужно:  Обеспечение исполнения обязательств по договору: требуется, в размере не менее 5 % от цены договора.
# Получил:  ['Размер обеспечения исполнения договора составляет 5 % от начальной (максимальной) цены договора']
#
# Нужно:  не предусмотрено увеличенное от первоначально установленного обеспечения исполнения договора в 1,5 (полтора) раза, но не более 5% (пяти) от начальной (максимальной) цены договора
# Получил:  ['не предусмотрено увеличенное от первоначально установленного обеспечения исполнения договора в 1,5 (полтора) раза, но не более 5% (пяти) от начальной (максимальной) цены договора (цены лота)']
#
# Нужно:  Устанавливается требование обеспечения исполнения Договора на участие в запросе котировок в размере - 5%- 17 416,70 (семнадцать тысяч четыреста шестнадцать) рублей
# Получил:  ['Размер обеспечения исполнения договора 2 606 259,96 руб. (30 % от НМЦД)']
#
# Нужно:  Обеспечение гарантийных обязательств по Договору Устанавливается 5% от начальной максимальной цены договора
# Получил:  []
#
# Нужно:  договор заключается только после предоставления таким участником обеспечения исполнения договора в размере 25% начальной (максимальной) цены договора
# Получил:  []
#
# Нужно:  Поставщик предоставляет обеспечение исполнения Договора в размере 5% от начальной (максимальной) цены договора, что составляет _
# Получил:  ['Поставщик предоставляет обеспечение исполнения Договора в размере 5% от начальной (максимальной) цены договора']
#
# Нужно:  Размер такого обеспечения не может превышать 30 (тридцати) процентов начальной (максимальной) цены договора.
# Получил:  ['Поставщик предоставляет обеспечение исполнения Договора в размере 5% от начальной (максимальной) цены договора']
#
# Нужно:  Если договором не предусмотрен авансовый порядок расчетов, обеспечение по договору предоставляется в размере 5% от начальной (максимальной) цены договора (с НДС)
# Получил:  ['Обеспечение исполнения обязательств по договору предоставляется до заключения Договора.']
#
# Нужно:  Размер обеспечения исполнения договора устанавливается от 5 до 30 процентов начальной (максимальной) цены договора
# Получил:  ['Размер обеспечения исполнения договора устанавливается от 5 до 30 процентов начальной (максимальной) цены договора (цены лота, максимального значения цены договора)']
#
# Нужно:  Исполнителем предоставлено Заказчику обеспечение исполнения настоящего Договора в размере 68 640,00 рублей. НДС не облагается.
# Получил:  ['Размер обеспечения исполнения договора устанавливается от 5 до 30 процентов начальной (максимальной) цены договора (цены лота, максимального значения цены договора)']
#
# Нужно:  Обеспечение исполнения Договора, предоставляется на сумму 5 % от начальной максимальной цены Договора
# Получил:  ['Размер обеспечения исполнения договора устанавливается от 5 до 30 процентов начальной (максимальной) цены договора (цены лота, максимального значения цены договора)']
#
# Нужно:  обеспечение предоставляется в размере 5% от начальной (максимальной) цены договора
# Получил:  ['Размер обеспечения исполнения договора устанавливается от 5 до 30 процентов начальной (максимальной) цены договора (цены лота, максимального значения цены договора)']
#
# Нужно:  Размер обеспечения: 5 % - 89 500,00 (восемьдесят девять тысяч пятьсот) рублей 00
# Получил:  ['Размер обеспечения: 5 % - 89 500,00 (восемьдесят девять тысяч пятьсот) рублей 00 копейки.']
#
# Нужно:  Обеспечение исполнения настоящего договора предоставляется поставщиком в размере: 5% начальной (максимальной) цены договора на сумму: 44000,00
# Получил:  ['Размер обеспечения: 5 % - 89 500,00 (восемьдесят девять тысяч пятьсот) рублей 00 копейки.']
#
# Нужно:  обеспечения исполнения договора в размере, превышающем в полтора раза размер обеспечения исполнения договора, указанный в документации о закупке, но не менее, чем 10 (десять) процентов от начальной (максимальной) цены договора
# Получил:  ['Размер обеспечения: 5 % - 89 500,00 (восемьдесят девять тысяч пятьсот) рублей 00 копейки.']
#
# Нужно:  Подрядчик внес обеспечение Договора на сумму: 0 (ноль) рублей 0 (ноль) копеек
# Получил:  ['Размер обеспечения: 5 % - 89 500,00 (восемьдесят девять тысяч пятьсот) рублей 00 копейки.']
#
# Нужно:  Поставщик предоставляет обеспечение исполнения Договора в размере 5 % от начальной максимальной цены Договора на сумму 13 945
# Получил:  ['Поставщик предоставляет обеспечение исполнения Договора в размере 5 % от начальной максимальной цены Договора на сумму 13 945 руб. 57 коп.']
#
# Нужно:  Обеспечение исполнения гражданско-правового договора установлено в размере 5% от начальной (максимальной) цены договора
# Получил:  ['Поставщик предоставляет обеспечение исполнения Договора в размере 5 % от начальной максимальной цены Договора на сумму 13 945 руб. 57 коп.']
#
# Нужно:  требование об обеспечении исполнения договора в пределах от 5 до 30 процентов начальной (максимальной) цены договора
# Получил:  ['Обеспечение исполнения Договора устанавливается в размере 5 процент(ов,а) начальной (максимальной) цены договора.']
#
# Нужно:  Поставщик предоставляет обеспечение исполнения Договора в размере 5 % от начальной максимальной цены Договора на сумму 7 447
# Получил:  ['Поставщик предоставляет обеспечение исполнения Договора в размере 5 % от начальной максимальной цены Договора на сумму 7 447 рублей 50 копеек в форме внесения денежных средств']
#
# Нужно:  такое лицо предоставляет обеспечение исполнения договора в размере 7,5 % от НМЦ.
# Получил:  ['размер увеличения обеспечения договора при применении антидемпинговых мер.']
#
# Нужно:  такое лицо предоставляет обеспечение исполнения договора в размере 7,5 % от НМЦ.
# Получил:  ['размер увеличения обеспечения договора при применении антидемпинговых мер.']
#
# Нужно:  Размер обеспечения договора 10 % от НМЦ
# Получил:  ['Размер обеспечения договора 10 % от НМЦ составляет: 15 687,12 (']
#
# Нужно:  предоставление таким участником обеспечения договора в размере 5 процентов от начальной максимальной цены договора
# Получил:  ['Размер обеспечения договора 10 % от НМЦ составляет: 15 687,12 (']
#
# Нужно:  участник закупки обязан представить вместе с подписанным проектом договора обеспечение исполнения договора в размере 10 (десяти) процентов от начальной (максимальной) цены договора
# Получил:  ['Принять к сведению, что Исполнитель внес обеспечение исполнения Договора на сумму 0 (нуль) рублей 00 копеек.']
#
# Нужно:  Заказчиком установлено обеспечение исполнения договора в размере 10 % от начальной (максимальной) цены договора
# Получил:  []
#
# Нужно:  В размере 5% от начальной максимальной цены Договора в сумме 15801,15
# Получил:  ['В размере 5% от начальной максимальной цены Договора в сумме 15801,15 руб.']
#
# Нужно:  Обеспечение исполнения договора представляется в размере 5 % от начальной (максимальной) цены договора в сумме _________
# Получил:  ['Обеспечение исполнения договора представляется в размере 5 % от начальной (максимальной) цены договора']
#
# Нужно:  Обеспечение исполнения договора, срок и порядок его предоставления 5% от начальной цены договора, что составляет 3 381 руб. 22
# Получил:  ['В целях обеспечения исполнения обязательств по договору Исполнитель представляет Заказчику обеспечение исполнения договора в размере 5 (пять) процентов от начальной (максимальной) цены договора']
#
# Нужно:  Размер обеспечения исполнения договора: 5% от начальной (максимальной) цены договора 18 971,89 руб.
# ...
# Получил:  ['Размер обеспечения гарантийных обязательств 904.66 Российский рубль']
#
# Нужно:  Генеральный подрядчик обязан предоставить Заказчику обеспечение исполнения гарантийных обязательств. Обеспечение гарантийных обязательств установлено в размере 2 % начальной (максимальной) цены Договора, что составляет 8 807 296 руб. 20 коп.
# Получил:  ['Обеспечение гарантийных обязательств установлено в размере 2 % начальной (максимальной) цены Договора, что составляет 8 807 296 руб. 20 коп.']
#
# Нужно:  Размер обеспечения гарантийных обязательств Установлено 10% от начальной (максимальной) цены договора: 587 291
# Получил:  ['Размер обеспечения гарантийных обязательств Установлено 10% от начальной (максимальной) цены договора: 587 291 (пятьсот восемьдесят семь тысяч двести девяносто один) рубль 17 копеек, НДС не облагается.']
#
# Нужно:  Если договором предусмотрено предоставление обеспечения гарантийных обязательств, размер такого обеспечения может составлять от 0,01% до 10% от цены договора (лота) (максимального значения цены договора).
# Получил:  ['Установлен Размер обеспечения гарантийных обязательств: 5 % от начальной (максимальной) цены договора, что составляет 206 650']
#
# Нужно:  Гарантийное удержание является способом обеспечения надлежащего исполнения обязательств Принципала. Бенефициар производит выплату гарантийного удержания в размере 5% (пяти процентов) от Договорной цены Продукции с отсрочкой платежа не менее 30 и не более 60 календарных дней
# Получил:  ['Гарантийное удержание является способом обеспечения надлежащего исполнения обязательств Принципала. Бенефициар производит выплату гарантийного удержания в размере 5% (пяти процентов) от Договорной цены Продукции с отсрочкой платежа не менее 30 и не более 60 календарных дней после подписания Сторонами Акта приемки Продукции по качеству (далее - Гарантийное удержание), с учетом п.3.6 Соглашения.']
#
# Нужно:  обеспечение исполнения гарантийных обязательств – в размере 5% от Цены Договора.
# Получил:  []
#
# Нужно:  согласно п. 3.1. Договора Поставщик представляет Заказчику обеспечение гарантийных обязательств на поставленные товары. Размер обеспечения гарантийных обязательств: 1% от начальной (максимальной) цены контракта (договора), что составляет 125 350,10 рублей
# Получил:  ['Договора Поставщик представляет Заказчику обеспечение гарантийных обязательств на поставленные товары.', 'Размер обеспечения гарантийных обязательств: 1% от начальной (максимальной) цены контракта (договора), что составляет 125 350,10 рублей (сто двадцать пять тысяч триста пятьдесят рублей 10 копеек).']
#
# Нужно:  Обеспечение исполнения договора, гарантийных обязательств.
# Получил:  []
#
# Нужно:  Обеспечение исполнения гарантийных обязательств устанавливается в размере 5 % от НМЦК
# Получил:  ['Обеспечение исполнения гарантийных обязательств устанавливается в размере 5 % от НМЦК 13.5.1 Срок и порядок предоставления обеспечения исполнения гарантийных обязательств в виде независимой гарантии Срок действия независимой гарантии должен превышать предусмотренный договором срок исполнения обязательств, которые должны быть обеспечены такой независимой гарантией, не менее чем на один месяц.']
#
# Нужно:  Размер обеспечения исполнения договора и/или обеспечения исполнения гарантийных обязательств, срок и порядок их предоставления и возврата, требования к такому обеспечению 5 % от начальной (максимальной) цены договора в сумме 100 785.10 руб.
# Получил:  ['Установлен Размер обеспечения гарантийных обязательств: 10 % от начальной (максимальной) цены договора, что составляет 19 953']
#
# Нужно:  Обеспечение гарантийных обязательств по Договору Устанавливается 5% от начальной максимальной цены договора
# Получил:  ['Размер обеспечения гарантийных обязательств не предусмотрено', 'Размер обеспечения гарантийных обязательств не может превышать 20% от начальной (максимальной) цены договора.']
#
# Нужно:  размер банковской гарантии на обеспечение гарантийных обязательств определяется в размере 5% (пяти процентов) от цены Договора в редакции Дополнительного соглашения
# Получил:  ['Размер обеспечения гарантийных обязательств подрядчика устанавливается в размере 5% от начальной (максимальной) цены договора и составляет ___________.']
#
# Нужно:  к участникам закупки устанавливается требование преставления обеспечения гарантийных обязательств в размере 1% от начальной (максимальной) цены Договора.
# Получил:  ['Размер обеспечения гарантийных обязательств подрядчика устанавливается в размере 5% от начальной (максимальной) цены договора и составляет ___________.']
#
# Нужно:  взамен ранее предоставленного обеспечения гарантийных обязательств новое обеспечение гарантийных обязательств.
# Получил:  ['Обеспечение гарантийных обязательств устанавливается в размере 10 процентов от начальной (максимальной) цены договора и составляет ___________________________.']
#
# Нужно:  если Заказчиком установлено требование обеспечения исполнения договора и/или обеспечения исполнения гарантийных обязательств.
# Получил:  []
#
# Нужно:  Обеспечение гарантийных обязательств: Не установлено
# Получил:  []
#
# Нужно:  Размер обеспечения исполнения обязательств на период действия гарантийных обязательств Размер и валюта обеспечения: 2% от начальной (максимальной) цены договора: 216 673,80 рублей
# Получил:  []
#
# Нужно:  Требование об обеспечении исполнения гарантийных обязательств Устанавливается Размер обеспечения исполнения гарантийных обязательств: 5 % от начальной (максимальной) цены договора
# Получил:  ['Размер обеспечения исполнения гарантийных обязательств: 5 % от начальной (максимальной) цены договора']
#
# Нужно:  Подрядчик обязан предоставить Заказчику обеспечение гарантийных обязательств на сумму ________ руб. (_______________ рублей __ копеек), что составляет 0,1% от цены Договора, в форме _____________ (независимой гарантии или путем внесения денежных средств
# Получил:  ['Подрядчик обязан предоставить Заказчику обеспечение гарантийных обязательств на сумму ________ руб. (_______________ рублей __ копеек), что составляет 0,1% от цены Договора, в форме _____________ (независимой гарантии']
#
# Нужно:  Размер обеспечения исполнения обязательств Участника в гарантийный период составляет не менее 5 (пяти) процентов от цены сделки - для сделок с ценой не более 100 млн рублей
# Получил:  ['Сумма обеспечения исполнения гарантийных обязательств предусмотрена в следующем размере: 0,1 % от цены предложенной победителем закупки, НДС не облагается.']
#
# Нужно:  взамен ранее предоставленного обеспечения гарантийных обязательств новое обеспечение гарантийных обязательств.
# Получил:  ['Размер обеспечения гарантийных обязательств не может превышать 10 процентов от НМЦД.']
#
# Нужно:  Подрядчик обязан предоставить Заказчику обеспечение гарантийных обязательств на сумму ________ руб. (_______________ рублей __ копеек), что составляет 0,1% от цены Договора, в форме _____________ (независимой гарантии или путем внесения денежных средств
# Получил:  ['Подрядчик обязан предоставить Заказчику обеспечение гарантийных обязательств на сумму ________ руб. (_______________ рублей __ копеек), что составляет 0,1% от цены Договора, в форме _____________ (независимой гарантии']
#
# Нужно:  Подрядчик обязан предоставить Заказчику обеспечение гарантийных обязательств на сумму ________ руб. (_______________ рублей __ копеек), что составляет 0,1% от цены Договора, в форме _____________ (независимой гарантии или путем внесения денежных средств
# Получил:  ['Подрядчик обязан предоставить Заказчику обеспечение гарантийных обязательств на сумму ________ руб. (_______________ рублей __ копеек), что составляет 0,1% от цены Договора, в форме _____________ (независимой гарантии']
#
# Нужно:  Обеспечение исполнения гарантийных обязательств устанавливается в размере 5 % от начальной (максимальной) цены заключенного договора ______________
# Получил:  ['Обеспечение исполнения гарантийных обязательств устанавливается в размере 5 % от начальной (максимальной) цены заключенного договора ______________ в виде внесение денежных средств']
#
# Нужно:  Поставщик представляет Заказчику обеспечение гарантийных обязательств на сумму 5% от суммы начальной (максимальной) цены Договора, что составляет: 19 500,00
# Получил:  ['Размер обеспечения гарантийных обязательств составляет 23 977 (двадцать три тысячи девятьсот семьдесят семь) руб. 21 коп. (пять процентов начальной (максимальной) цены договора).']
#
# Нужно:  Размер обеспечения исполнения гарантийных обязательств составляет 10% 198 449,93 рублей, НДС не облагается.
# Получил:  ['Размер обеспечения гарантийных обязательств составляет 23 977 (двадцать три тысячи девятьсот семьдесят семь) руб. 21 коп. (пять процентов начальной (максимальной) цены договора).']
#
# Нужно:  Подрядчик обязан предоставить Заказчику обеспечение гарантийных обязательств на сумму ________ руб. (_______________ рублей __ копеек), что составляет 3 % от цены Договора, в форме _____________ (независимой гарантии или путем внесения денежных средств
# Получил:  ['Подрядчик обязан предоставить Заказчику обеспечение гарантийных обязательств на сумму ________ руб. (_______________ рублей __ копеек), что составляет 3 % от цены Договора, в форме _____________ (независимой гарантии']
#
# Нужно:  Размер обеспечения исполнения Договора и (или) обеспечения исполнения гарантийных обязательств, срок и порядок их предоставления Обеспечение исполнения Договора составляет - 15% от начальной (максимальной) цены Договора, что составляет 5 006 444
# Получил:  []
#
# Нужно:  Размер обеспечения исполнения договора (или) гарантийных обязательств. Установлено в размере 5 (пяти) % от начальной максимальной цены Договора на сумму 90 200 (Девяносто тысяч двести) рублей 42 копейки.
# Получил:  ['Сумма обеспечения гарантийных обязательств предусмотрено в следующем размере: - 2 % от начальной (максимальной) цены договора, что составляет: 244 997,60 руб., НДС не облагается.']
#
# Нужно:  Размер обеспечения гарантийных обязательств составляет 5% от НМЦД- 65916,57 (Шестьдесят пять тысяч девятьсот шестнадцать) рублей 57 копеек. НДС не облагается
# Получил:  ['Размер обеспечения гарантийных обязательств составляет 5% от НМЦД- 65916,57 (Шестьдесят пять тысяч девятьсот шестнадцать) рублей 57 копеек. НДС не облагается.']
#
# Нужно:  Поставщик может предоставить Покупателю в качестве обеспечения исполнения гарантийных обязательств безусловную и безотзывную банковскую гарантию на сумму равную не менее 5% (пять процентов) от стоимости работ.
# Получил:  ['Размер обеспечения гарантийных обязательств составляет 5% от НМЦД- 65916,57 (Шестьдесят пять тысяч девятьсот шестнадцать) рублей 57 копеек. НДС не облагается.']
#
# Нужно:  Размер обеспечения исполнения гарантийных обязательств составляет: _________0__________ рублей, НДС не облагается. Срок предоставления обеспечения исполнения гарантийных обязательств: ________
# Получил:  ['Размер обеспечения исполнения гарантийных обязательств составляет: _________0__________ рублей, НДС не облагается. Срок предоставления обеспечения исполнения гарантийных обязательств: __________________________________________ Минимальный срок гарантийных обязательств: ___________________________________________ Порядок предоставления обеспечения исполнения гарантийных обязательств: в соответствии с частью IX «ПРОЕКТ ДОГОВОРА» извещении 25.']
#
# Нужно:  Размер обеспечения гарантийных обязательств установлен в размере 20% от НМЦД: 1 644 839,76 рублей. Гарантийные обязательства обеспечиваются внесением денежных средств участником закупки
# Получил:  ['Размер обеспечения гарантийных обязательств установлен в размере 20% от НМЦД: 1 644 839,76 рублей.']
#
# Нужно:  Размер обеспечения гарантийных обязательств установлен в размере 20% от НМЦД: 1 644 839,76 рублей. Гарантийные обязательства обеспечиваются внесением денежных средств участником закупки
# Получил:  ['Размер обеспечения гарантийных обязательств установлен в размере 20% от НМЦД: 1 644 839,76 рублей.']
#
# Нужно:  взамен ранее предоставленного обеспечения гарантийных обязательств новое обеспечение гарантийных обязательств.
# Получил:  ['Размер обеспечения гарантийных обязательств установлен в размере 20% от НМЦД: 1 644 839,76 рублей.']
#
# Нужно:  Если договором предусмотрено предоставление обеспечения гарантийных обязательств, размер такого обеспечения может составлять от 0,01% до 10% от цены договора (лота) (максимального значения цены договора).
# Получил:  ['Размер обеспечения гарантийных обязательств установлен в размере 20% от НМЦД: 1 644 839,76 рублей.']
#
# Нужно:  Предоставление Подрядчиком обеспечения гарантийных обязательств в размере 5 % от начальной (максимальной) цены Договора, что составляет что составляет 584 558
# Получил:  ['Размер обеспечения гарантийных обязательств: Требование установлено.']
#
# Нужно:  размер банковской гарантии на обеспечение гарантийных обязательств определяется не менее 5% (пяти процентов) от цены Договора в редакции Дополнительного соглашения
# Получил:  ['Размер обеспечения исполнения гарантийных обязательств не может превышать 2 % начальной (максимальной) цены договора (цены лота).']
#
# Нужно:  Обеспечение возврата аванса и/или гарантийных обязательств: не установлено
# Получил:  ['Обеспечение возврата аванса и/или гарантийных обязательств: не установлено 30.']
#
# Нужно:  Обеспечение исполнения договора №_______ на________ Требование об обеспечении исполнения гарантийных обязательств Устанавливается Размер обеспечения исполнения гарантийных обязательств: 5 % от начальной (максимальной) цены договора
# Получил:  ['Размер обеспечения исполнения гарантийных обязательств: 5 % от начальной (максимальной) цены договора']
#
# Нужно:  Обеспечение гарантийных обязательств по договору ☒ Не требуется. ☐ Сумма обеспечения гарантийных обязательств по договору составляет 10% от цены договора.
# Получил:  ['Обеспечение гарантийных обязательств по договору ☒ Не требуется.']
#
# Нужно:  НДС 20%, сборы и иные обязательные платежи, а также все расходы, связанные с обеспечением гарантийных обязательств.
# Получил:  ['Обеспечение гарантийных обязательств по договору ☒ Не требуется.']
#
# Нужно:  Размер обеспечения гарантийных обязательств не может превышать 10 процентов НМЦД. Обеспечение исполнения гарантийных обязательств может быть предоставлено поставщиком
# Получил:  ['Размер обеспечения гарантийных обязательств не может превышать 10 процентов НМЦД.']
#
# Нужно:  Устанавливается Размер обеспечения исполнения гарантийных обязательств: 5 % от начальной (максимальной) цены договора
# Получил:  ['Размер обеспечения исполнения гарантийных обязательств: 5 % от начальной (максимальной) цены договора']
#
# Нужно:  взамен ранее предоставленного обеспечения гарантийных обязательств новое обеспечение гарантийных обязательств.
# Получил:  ['Обеспечение гарантийных обязательств устанавливается в размере 1 % начальной (максимальной) цены контракта.']
#
# Нужно:  срок действия гарантийных обязательств не менее чем на один месяц. Размер обеспечения Исполнение гарантийного обязательства по Контракту составляет 5% от начальной (максимальной) цены Контракта.
# Получил:  ['Обеспечение гарантийных обязательств устанавливается в размере 1 % начальной (максимальной) цены контракта.']
#
# Нужно:  Субподрядчик в качестве обеспечения надлежащего исполнения гарантийных обязательств по Договору предоставляет Подрядчику право на удержание в общем размере 2% от цены Договора (включая НДС), указанной в пункте 3.1. Договора (далее Гарантийное удержание).
# Получил:  ['Размер обеспечения исполнения гарантийных обязательств не может превышать 2 % начальной (максимальной) цены договора (цены лота) и устанавливается в Специальной части.']
#
# Нужно:  Заказчиком установлено требование обеспечения исполнения договора и (или) обеспечения исполнения гарантийных обязательств. 5% от начальной (максимальной) цены договора, что составляет 27450
# Получил:  ['Заказчиком установлено требование обеспечения исполнения договора и (или) обеспечения исполнения гарантийных обязательств. 5% от начальной (максимальной) цены договора, что составляет 27450 (Двадцать семь тысяч четыреста пятьдесят) рублей 00 копеек в форме независимой гарантии']

# %% [markdown]
# Исправленная метрика 0.7987721691678036
# Базовая  0.7939972714870396

# %%
#print(data_train[0][0])
doc = nlp(data_train[4][0])
print(doc.spans)

# %%
data_train[0]

# %%
try:
    s = re.search(str(max(list(doc.ents), key=len)), data[0][0])
    #print(s.span())
    #print(data[i][0][s.start():s.end()])
except Exception as e:
    pass

# %% [markdown]
# ### Тестирование теорий

# %%
text_test = data_train[0][0]

left = data_train[0][1].get('entities')[0]#[0]
right = data_train[0][1].get('entities')[0]#[1]
#print(text_test[left:right])
left

# %%
doc = nlp(text_test)
print(doc.ents[0])
for ent in doc.ents:
    print(ent.label_)
    print(ent.text)

# %% [markdown]
# Такая задача называется извлечением информации (Information Extraction) или извлечением сущностей (Named Entity Recognition). В этой задаче используются метки, такие как имена собственные, даты, адреса, организации, и т.д., чтобы извлечь соответствующие куски текста. В области NLP существует также подзадача извлечения отношений между сущностями (Relation Extraction), где необходимо определить отношение между двумя или более сущностями в тексте.
